# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import time

# %%
url = 'https://www.remax.ca/ab/calgary-real-estate/13-auburn-bay-green-se-wp_id278637256-lst'

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- Relative links in this file are replaced in prepare_index.py -->
# <html lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# og: http://ogp.me/ns#">
#  <head>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <!--ROBOTTAG-->
#   <title>
#    Calgary Real Estate - Houses for Sale Calgary | RE/MAX Canada
#   </title>
#   <meta content="View all Calgary real estate with Canada's #1 Real Estate Brand. Search houses for sale in Calgary, Alberta, MLSÂ® listings details, townhomes and all other property. Discover your next Calgary home with RE/MAX." name="description"/>
#   <base href="/"/>
#   <!-- For iOS safari -->
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <!-- Use full Screen -->
#   <meta content="translucent black" name="apple-mobile-web-app-status-bar-style"/>
#   <!-- Homescreen Title -->
#   <meta content="RE/MAX" name="apple-mobile-web-app-title"/>
#   <!-- Homescreen Icon -->
#   <link href="https://remax-prodapp.imgix.net/assets/icons/app-icons/iOS/Icon-76@2x.png" rel="apple-touch-icon"/>
#   <!-- Open Graph -->
#   <meta content="calgary Real Estate - Houses for Sale calgary | RE/MAX Canada" property="og:title"/>
#   <meta content="View all calgary real estate with Canada's #1 Real Estate Brand. Search houses for sale in calgary, ab, MLSÂ® listings details, townhomes and all other property. Discover your next calgary home with RE/MAX." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.remax.ca/ab/calgary-real-estate" property="og:url"/>
#   <meta content="RE/MAX" property="og:site_name"/>
#   <meta content="https://remax-prodapp.imgix.net/assets/REMAX_Logo/REMAX_Residential_og.png" property="og:image"/>
#   <meta content="" property="place:location:latitude"/>
#   <meta content="" property="place:location:longitude"/>
#   <meta content="" property="og:details"/>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-KBCTLC8');
#   </script>
#   <meta content="D66A8C75570A35CCADCD31FD6ACBD175" name="msvalidate.01"/>
#   <!-- for Android Chrome -->
#   <link href="https://remax-prodapp.imgix.net/manifest.json" rel="manifest"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="#004E9B" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://remax-prodapp.imgix.net/assets/favicon_32x32.png" rel="icon" type="image/x-icon"/>
#   <!-- External Scripts -->
#   <!-- We set the media and onload to change these calls to non-blocking calls-->
#   <link as="style" crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/Swiper/4.2.6/css/swiper.min.css" rel="preload"/>
#   <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/Swiper/4.2.6/css/swiper.min.css" media="none" onload="this.media='all';" rel="stylesheet"/>
#   <link as="style" crossorigin="anonymous" href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" media="none" onload="this.media='all';" rel="stylesheet"/>
#   <!-- <link crossorigin="anonymous" rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" media="none" onload="this.media='all';"> -->
#   <link as="style" crossorigin="anonymous" href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://fonts.googleapis.com/icon?family=Material+Icons" media="none" onload="this.media='all';" rel="stylesheet"/>
#   <link href="assets/css/bootstrap.min.css" media="none" onload="this.media='all'" rel="stylesheet"/>
#   <script>
#    global_ngEnvOverride = 'prod';
#         global_versionNumber = '1.0.0.1737';
#   </script>
#   <link href="https://remax-prodapp.imgix.net/styles.bd4286621d919ded3133.css" rel="stylesheet"/>
#   <style ng-transition-rmx="remaxdotca">
#    @media (min-width:600px){.main-content[_ngcontent-sc0]{width:100%;background-color:#fff}}@media (min-width:1200px){.main-content[_ngcontent-sc0]{padding-left:5%;padding-right:5%}}@media (min-width:1800px){.main-content[_ngcontent-sc0]{padding-left:12%;padding-right:12%}}.main-content.unpadded[_ngcontent-sc0]{padding:0}.app-container[_ngcontent-sc0]{position:relative;flex-direction:column;min-height:100%}.app-container.has-side-nav[_ngcontent-sc0]{width:100vw}@media (max-width:1199px){.app-container[_ngcontent-sc0]{height:100%}}.app-container.remove-full-height[_ngcontent-sc0]{height:unset}.modal-backdrop[_ngcontent-sc0]{left:0;top:0;background-color:rgba(0,0,0,.7);z-index:200}app-header[_ngcontent-sc0]{z-index:11}app-side-nav.is-menu[_ngcontent-sc0]{z-index:12}.search[_ngcontent-sc0]{top:0;background-color:#fff}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .error-container[_ngcontent-sc2]{position:fixed;top:10px;right:10px;z-index:113}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]{position:relative;overflow:hidden;width:360px;height:80px;background:#fff;margin:10px 10px 0 0;border-radius:10px;border:3px solid red;display:flex;flex-direction:row;justify-content:flex-start;align-items:center}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]   .error-icon[_ngcontent-sc2]{flex:0 0 auto;color:red;font-size:32px;padding:0 24px}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]   .error-text[_ngcontent-sc2]{flex:0 0 auto;padding-right:40px;height:100%}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]   .error-text[_ngcontent-sc2] > *[_ngcontent-sc2]{flex:0 0 auto}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]   .error-text[_ngcontent-sc2]   [_ngcontent-sc2]:first-child{margin:0 0 5px;line-height:20px}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]   .error-text[_ngcontent-sc2]   [_ngcontent-sc2]:first-child   h4[_ngcontent-sc2]{margin:0 10px 0 0}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]   .error-text[_ngcontent-sc2]   [_ngcontent-sc2]:first-child   .error-code[_ngcontent-sc2]{height:18px;font-size:12px;color:rgba(1,1,1,.4)}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]   .close-icon[_ngcontent-sc2]{cursor:pointer;position:absolute;top:5px;right:5px}@media (max-width:599px){.error-container[_ngcontent-sc2]{top:0;right:0}.error-container[_ngcontent-sc2]   .error[_ngcontent-sc2]{width:calc(100vw - 20px);margin:10px 10px 0}}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    [_nghost-sc3]     nav{z-index:11;width:100vw;height:100vh;background-color:#fff;overflow-x:hidden;overflow-y:auto;display:flex;flex-direction:column;position:absolute}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .drawer[_ngcontent-sc9]{z-index:100;white-space:nowrap;overflow-y:auto;position:fixed;bottom:0;left:0;right:0;height:100%;background-color:#fff}.drawer-content[_ngcontent-sc9]{height:100%;overflow-y:auto}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    nav[_ngcontent-sc12]{background-color:#fff;margin-bottom:20%}nav[_ngcontent-sc12]   p[_ngcontent-sc12]{margin-top:12px}nav[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]{flex-shrink:0}nav[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]   li[_ngcontent-sc12]{padding:10px}nav[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]   li[_ngcontent-sc12]   i[_ngcontent-sc12]{cursor:pointer;font-weight:700;color:#004e9b}nav[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]   .active-logo[_ngcontent-sc12]{margin-left:8%}nav[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]:nth-of-type(1){margin-top:6px;margin-bottom:2px}nav[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]:nth-of-type(2){justify-content:space-around;margin-bottom:auto}nav.type-LUXURY[_ngcontent-sc12]{background:linear-gradient(45deg,#2b5885,#003b76)}nav.type-LUXURY[_ngcontent-sc12]   p[_ngcontent-sc12]{color:#fff}nav.type-LUXURY[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]:first-of-type{border-bottom-width:8px;border-bottom-style:solid;-o-border-image:linear-gradient(90deg,#7e8083 35%,#c4c6c8,#fff,#c4c6c8,#7e8083 65%) 17%/0 0 8px 0/0 round;border-image:linear-gradient(90deg,#7e8083 35%,#c4c6c8,#fff,#c4c6c8,#7e8083 65%) 17%/0 0 8px 0/0 round}nav.type-LUXURY[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]   li[_ngcontent-sc12]   i[_ngcontent-sc12]{color:#fff}nav.type-COMMERCIAL[_ngcontent-sc12]   .nav.category[_ngcontent-sc12]   li[_ngcontent-sc12]   i[_ngcontent-sc12], nav.type-COMMERCIAL[_ngcontent-sc12]   p[_ngcontent-sc12]{color:#2d2d2d}@media (min-width:600px){.active[_nghost-sc12]:before{content:'';width:100vw;height:100%;display:block;position:absolute;background:#949ca1;opacity:.3;z-index:-1}nav[_ngcontent-sc12]{width:60vw;box-shadow:0 2px 16px 32px rgba(0,0,0,.3)}}@media (min-width:1200px){.overlay[_ngcontent-sc12]{display:none}}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .remax-gradient-blue[_ngcontent-sc13], nav[_ngcontent-sc13]   header[_ngcontent-sc13]{background-image:linear-gradient(90deg,#0054a4 0,#002b5c 100%);background-repeat:repeat-x}.remax-gradient-dark-blue[_ngcontent-sc13]{background-image:linear-gradient(28.79898555deg,#1159ac 0,#20345d 100%);background-repeat:repeat-x}.remax-gradient-gray[_ngcontent-sc13], nav.type-COMMERCIAL[_ngcontent-sc13]   header[_ngcontent-sc13]{background-image:linear-gradient(90deg,#454647 0,#1e1c1c 100%);background-repeat:repeat-x}.remax-gradient-red[_ngcontent-sc13]{background-image:linear-gradient(90deg,#e11b22 0,#b30b30 100%);background-repeat:repeat-x}.remax-gradient-white[_ngcontent-sc13], nav[_ngcontent-sc13]{background-image:linear-gradient(90deg,#fbfcfd 0,#f6f7f9 100%);background-repeat:repeat-x}.remax-gradient-light-blue[_ngcontent-sc13]{background-image:linear-gradient(45deg,#0086cb 0,#1f335e 100%);background-repeat:repeat-x}.remax-basic-box-shadow[_ngcontent-sc13]{box-shadow:0 2px 4px 0 rgba(0,0,0,.1)}.btn[_ngcontent-sc13]{padding:10px 30px;border-radius:2px;box-shadow:4px 4px 11px 1px rgba(0,0,0,.25)}.btn[_ngcontent-sc13]   svg[_ngcontent-sc13]{vertical-align:middle}.btn[disabled][_ngcontent-sc13]{cursor:not-allowed}.btn.btn-primary[_ngcontent-sc13]{border-color:#b30b30;text-align:center;color:#fff;font-weight:300;background-repeat:repeat-x;background-image:linear-gradient(45deg,#dc1c2e,#b2292e)}.btn.btn-primary[_ngcontent-sc13]:focus, .btn.btn-primary[_ngcontent-sc13]:hover{background:#b2292e}.btn.btn-primary[disabled][_ngcontent-sc13]{background-image:linear-gradient(to bottom,#949ca1 0,#5f6062 100%);background-repeat:repeat-x;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#FF949CA1', endColorstr='#FF5F6062', GradientType=0);border-color:#949ca1}.btn.btn-secondary[_ngcontent-sc13]{background-image:linear-gradient(to bottom,#fff 50%,#f6f7f9 50%);background-repeat:repeat-x;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#FFFFFFFF', endColorstr='#FFF6F7F9', GradientType=0);border-color:#007dc3;text-align:center;color:#007dc3}.btn.btn-secondary[_ngcontent-sc13]:focus, .btn.btn-secondary[_ngcontent-sc13]:hover{background:#fbfcfd}.btn.btn-secondary[disabled][_ngcontent-sc13]{background-color:#fbfcfd;border-color:#fbfcfd;color:#f6f7f9}.btn.btn-fake[_ngcontent-sc13]{border:none;box-shadow:0 0 0 0 #fff;background:0 0}.btn-group[_ngcontent-sc13]{box-shadow:0 0 10px 0 #c4c6c8}.btn.btn-borderless[_ngcontent-sc13]{border:0}.btn.btn-flat-borders[_ngcontent-sc13]{border-radius:0}.btn.btn-circle[_ngcontent-sc13]{border-radius:100%;height:36px;width:36px;padding:0}.btn.btn-circle[_ngcontent-sc13]   i[_ngcontent-sc13]{vertical-align:text-top}.btn.btn-bold[_ngcontent-sc13]{font-weight:700}.btn.btn-full-sized[_ngcontent-sc13]{width:100%}.btn.btn-blue[_ngcontent-sc13]{background-image:linear-gradient(to bottom,#007dc3 0,#0054a4 100%);background-repeat:repeat-x;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#FF007DC3', endColorstr='#FF0054A4', GradientType=0);color:#fff}.btn.btn-luxury[_ngcontent-sc13], .btn.btn-luxury-base[_ngcontent-sc13], .btn.btn-luxury-inverted[_ngcontent-sc13]{border:0;padding:5px;font-family:Baskerville,serif;text-transform:uppercase;background-color:#fff}.btn.btn-luxury[_ngcontent-sc13]   span[_ngcontent-sc13], .btn.btn-luxury-base[_ngcontent-sc13]   span[_ngcontent-sc13], .btn.btn-luxury-inverted[_ngcontent-sc13]   span[_ngcontent-sc13]{display:inline-block;padding:15px 40px;font-family:Baskerville,serif;font-size:18px;font-weight:600;color:#004e9b;text-transform:uppercase;line-height:20px;white-space:normal}.btn.btn-persona[_ngcontent-sc13]{background-color:#002f6d;opacity:.9;color:#fff}.btn.btn-luxury[_ngcontent-sc13]   span[_ngcontent-sc13]{background-image:linear-gradient(90deg,#002f6d,rgba(0,78,155,.9),#002f6d);box-shadow:inset 0 0 16px 25px rgba(45,45,45,.25);color:#fff}.btn.btn-luxury-inverted[_ngcontent-sc13]{background-color:#c8c6c2;background-image:linear-gradient(to rig ...
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    @font-face{font-family:Gotham;font-weight:400;font-style:normal;src:local(Gotham-Book);src:url(https://remax-prodapp.imgix.net/assets/fonts/Gotham-Book.ttf) format("truetype");src:url(https://remax-prodapp.imgix.net/assets/fonts/Gotham-Book.otf) format("opentype")}@font-face{font-family:Gotham;font-weight:300;font-style:normal;src:local(Gotham-Light);src:url(https://remax-prodapp.imgix.net/assets/fonts/Gotham-Light.otf) format("opentype");src:url(https://remax-prodapp.imgix.net/assets/fonts/Gotham-Light.ttf) format("truetype")}@font-face{font-family:Gotham;font-weight:100;font-style:normal;src:local(Gotham-Thin);src:url(https://remax-prodapp.imgix.net/assets/fonts/Gotham-Thin.ttf) format("truetype");src:url(https://remax-prodapp.imgix.net/assets/fonts/Gotham-Thin.eot) format("opentype")}@font-face{font-family:Gotham;font-weight:600;font-style:normal;src:local(Gotham-Medium);src:url(https://remax-prodapp.imgix.net/assets/fonts/Gotham-Medium.ttf) format("truetype");src:url(https://remax-prodapp.imgix.net/assets/fonts/Gotham-Medium.otf) format("opentype")}@media only screen and (min-device-width:320px) and (max-device-height:480px) and (-webkit-device-pixel-ratio:1){input,select,textarea{font-size:16px!important}}@media only screen and (min-device-width:320px) and (max-device-height:480px) and (-webkit-device-pixel-ratio:2){input,select,textarea{font-size:16px!important}}@media only screen and (min-device-width:320px) and (max-device-height:568px) and (-webkit-device-pixel-ratio:2){input,select,textarea{font-size:16px!important}}@media only screen and (min-device-width:375px) and (max-device-height:667px) and (-webkit-device-pixel-ratio:2){input,select,textarea{font-size:16px!important}}@media only screen and (min-device-width:414px) and (max-device-height:736px) and (-webkit-device-pixel-ratio:3){input,select,textarea{font-size:16px!important}}@media only screen and (min-device-width:375px) and (max-device-height:812px) and (-webkit-device-pixel-ratio:3){input,select,textarea{font-size:16px!important}}form app-checkbox .has-error,form app-checkbox.has-errors,form app-input .has-error,form app-input.has-errors,form app-min-max-slider .has-error,form app-min-max-slider.has-errors,form app-radio-group .has-error,form app-radio-group.has-errors,form app-select .has-error,form app-select.has-errors,form app-switch .has-error,form app-switch.has-errors{color:#dc1c2e;border-color:#dc1c2e!important}form app-checkbox .has-error .error-clue,form app-checkbox .has-error label,form app-checkbox.has-errors .error-clue,form app-checkbox.has-errors label,form app-input .has-error .error-clue,form app-input .has-error label,form app-input.has-errors .error-clue,form app-input.has-errors label,form app-min-max-slider .has-error .error-clue,form app-min-max-slider .has-error label,form app-min-max-slider.has-errors .error-clue,form app-min-max-slider.has-errors label,form app-radio-group .has-error .error-clue,form app-radio-group .has-error label,form app-radio-group.has-errors .error-clue,form app-radio-group.has-errors label,form app-select .has-error .error-clue,form app-select .has-error label,form app-select.has-errors .error-clue,form app-select.has-errors label,form app-switch .has-error .error-clue,form app-switch .has-error label,form app-switch.has-errors .error-clue,form app-switch.has-errors label{color:#dc1c2e!important}form app-checkbox .has-error .form-control,form app-checkbox.has-errors .form-control,form app-input .has-error .form-control,form app-input.has-errors .form-control,form app-min-max-slider .has-error .form-control,form app-min-max-slider.has-errors .form-control,form app-radio-group .has-error .form-control,form app-radio-group.has-errors .form-control,form app-select .has-error .form-control,form app-select.has-errors .form-control,form app-switch .has-error .form-control,form app-switch.has-errors .form-control{border-color:#dc1c2e!important}form .show-hide{color:#004e9b}form .form-control-feedback,form .form-c ...
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .remax-gradient-blue[_ngcontent-sc4]{background-image:linear-gradient(90deg,#0054a4 0,#002b5c 100%);background-repeat:repeat-x}.remax-gradient-dark-blue[_ngcontent-sc4]{background-image:linear-gradient(28.79898555deg,#1159ac 0,#20345d 100%);background-repeat:repeat-x}.remax-gradient-gray[_ngcontent-sc4]{background-image:linear-gradient(90deg,#454647 0,#1e1c1c 100%);background-repeat:repeat-x}.remax-gradient-red[_ngcontent-sc4]{background-image:linear-gradient(90deg,#e11b22 0,#b30b30 100%);background-repeat:repeat-x}.remax-gradient-white[_ngcontent-sc4]{background-image:linear-gradient(90deg,#fbfcfd 0,#f6f7f9 100%);background-repeat:repeat-x}.remax-gradient-light-blue[_ngcontent-sc4]{background-image:linear-gradient(45deg,#0086cb 0,#1f335e 100%);background-repeat:repeat-x}.remax-basic-box-shadow[_ngcontent-sc4]{box-shadow:0 2px 4px 0 rgba(0,0,0,.1)}@media (max-width:1199px){nav.navbar-default[_ngcontent-sc4]{padding-top:16px;padding-bottom:8px;border:none}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link[_ngcontent-sc4]{display:block}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link[_ngcontent-sc4]   img[_ngcontent-sc4]{width:140px}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link.link-LUXURY.active-LUXURY[_ngcontent-sc4]   img[_ngcontent-sc4]{width:200px}nav.navbar-default[_ngcontent-sc4]   button[_ngcontent-sc4]{display:initial}}nav.navbar-default[_ngcontent-sc4]{background-color:#fff;z-index:3;border-radius:0}nav.navbar-default[_ngcontent-sc4]   button[_ngcontent-sc4]{background-color:#fff;margin-top:0;margin-bottom:0}@media (max-width:900px){nav.navbar-default[_ngcontent-sc4]   button[_ngcontent-sc4]{padding-right:5%}}nav.navbar-default[_ngcontent-sc4]   button[_ngcontent-sc4]   i[_ngcontent-sc4]{color:#0054a4;font-weight:700}nav.navbar-default[_ngcontent-sc4]   button.navbar-toggle[_ngcontent-sc4]{padding-top:0}nav.navbar-default[_ngcontent-sc4]   a.favourites[_ngcontent-sc4]{margin:0 10px 9px;color:#002f6d}nav.navbar-default[_ngcontent-sc4]   a.favourites[_ngcontent-sc4]   .favourite-count[_ngcontent-sc4]{font-size:12px;color:#fff;background-color:#dc1c2e;border-radius:50%;width:20px;height:20px;top:-10px;left:-12px;text-align:center;line-height:20px;box-sizing:content-box}nav.navbar-default[_ngcontent-sc4]   a.account[_ngcontent-sc4]{margin:0 10px 9px}nav.navbar-default[_ngcontent-sc4]   a.account[_ngcontent-sc4]   app-circle-initials[_ngcontent-sc4]  .initials{color:#002f6d;border-color:#002f6d;width:30px;font-size:.945em;height:30px;border-width:2px}nav.navbar-default[_ngcontent-sc4]   .logo[_ngcontent-sc4]{flex:4}nav.navbar-default[_ngcontent-sc4]   .header-buttons[_ngcontent-sc4]{flex:2}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]{margin:0 auto}nav.navbar-default.type-LUXURY[_ngcontent-sc4]{background-image:linear-gradient(120deg,transparent,transparent 10%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 25%,transparent 0,transparent 35%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 37%,transparent 0,transparent 40%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 41%,transparent 0,transparent 50%,rgba(0,0,0,.2) 0,rgba(0,0,0,.2) 70%,transparent 0,transparent 72%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 73%,transparent 0,transparent 93%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 96%,transparent 0,transparent),linear-gradient(120deg,#133266,#153468)}nav.navbar-default.type-LUXURY[_ngcontent-sc4]   .platform[_ngcontent-sc4]{z-index:1}nav.navbar-default.type-LUXURY[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link[_ngcontent-sc4]{color:#fff}nav.navbar-default.type-LUXURY[_ngcontent-sc4]   .navbar-header[_ngcontent-sc4]   .navbar-toggle[_ngcontent-sc4]{display:inline;background:0 0}nav.navbar-default.type-LUXURY[_ngcontent-sc4]   .navbar-header[_ngcontent-sc4]   .navbar-toggle[_ngcontent-sc4]   i[_ngcontent-sc4]{color:#fff}nav.navbar-default.type-LUXURY[_ngcontent-sc4]   .favourites[_ngcontent-sc4]{border-right-color:#002e5c}nav.navbar-default.type-LUXURY[_ngcontent-sc4]   .favourites[_ngcontent-sc4]   ...
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    @media (min-width:600px){nav.navbar-default[_ngcontent-sc4]{padding-left:2.5%;padding-right:2.5%}}@media (min-width:1200px){nav.navbar-default[_ngcontent-sc4]{border:0;border-radius:0;background-color:#fff;padding:45px 5% 20px}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link[_ngcontent-sc4]{display:block}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link[_ngcontent-sc4]   img[_ngcontent-sc4]{width:88.52px;height:35.504px}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link.link-RESIDENTIAL.active-RESIDENTIAL[_ngcontent-sc4]   img[_ngcontent-sc4]{width:185.73px;height:36.216px}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link.link-LUXURY.active-COMMERCIAL[_ngcontent-sc4]   img[_ngcontent-sc4], nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link.link-LUXURY.active-RESIDENTIAL[_ngcontent-sc4]   img[_ngcontent-sc4]{width:115px;height:39px;position:relative;bottom:4px}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link.link-COMMERCIAL.active-COMMERCIAL[_ngcontent-sc4]   img[_ngcontent-sc4], nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link.link-LUXURY.active-LUXURY[_ngcontent-sc4]   img[_ngcontent-sc4]{width:141.328px;height:48.216px}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link[_ngcontent-sc4]:last-of-type{padding-right:0;display:flex;align-content:center;font-weight:300;font-size:1.4rem}nav.navbar-default[_ngcontent-sc4]   .platform[_ngcontent-sc4]   .link[_ngcontent-sc4]:last-of-type   .material-icons[_ngcontent-sc4]{font-size:20px}nav.navbar-default.type-LUXURY[_ngcontent-sc4]{border-bottom:2px solid #91a3b7;background-image:linear-gradient(120deg,transparent,transparent 10%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 25%,transparent 0,transparent 35%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 37%,transparent 0,transparent 40%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 41%,transparent 0,transparent 50%,rgba(0,0,0,.2) 0,rgba(0,0,0,.2) 70%,transparent 0,transparent 72%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 73%,transparent 0,transparent 93%,rgba(0,0,0,.1) 0,rgba(0,0,0,.1) 96%,transparent 0,transparent),linear-gradient(120deg,#133266,#153468)}nav.navbar-default.type-LUXURY[_ngcontent-sc4]   .navbar-header[_ngcontent-sc4]{padding:15px 0}nav.navbar-default[_ngcontent-sc4]:not(.type-RESIDENTIAL){padding-top:20px;padding-bottom:0}nav.navbar-default.type-COMMERCIAL[_ngcontent-sc4]   .navbar-header[_ngcontent-sc4]{padding:15px 0}.navbar-header[_ngcontent-sc4]{width:100%;height:100%;color:#fff}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]{align-items:center;flex:4;font-weight:400;max-width:1500px;margin:0 auto}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link[_ngcontent-sc4]{font-size:large;color:#4f504f;padding-right:32.49px}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link.link-global[_ngcontent-sc4]{order:4}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link.link-RESIDENTIAL.active-RESIDENTIAL[_ngcontent-sc4]{order:1;margin-right:auto;padding-left:0}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link.link-RESIDENTIAL.active-LUXURY[_ngcontent-sc4]{order:2}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link.link-RESIDENTIAL.active-LUXURY[_ngcontent-sc4]:after{content:"";height:50%;-ms-grid-row-align:center;align-self:center;border-right:1px dashed #5f6062;padding:0 32.49px 0 0}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link.link-RESIDENTIAL.active-COMMERCIAL[_ngcontent-sc4]{order:3}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link.link-RESIDENTIAL.active-COMMERCIAL[_ngcontent-sc4]:after{content:"";height:50%;-ms-grid-row-align:center;align-self:center;border-right:1px dashed #5f6062;padding:0 32.49px 0 0}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-sc4]   a.link.link-LUXURY.active-RESIDENTIAL[_ngcontent-sc4]{order:2}.navbar-header[_ngcontent-sc4]   .platform[_ngcontent-s ...
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    [_nghost-sc65]{flex-shrink:0}.close-ic[_ngcontent-sc65]{right:10px;top:10px}.extra-nav[_ngcontent-sc65]{display:none}app-modal[_ngcontent-sc65]     .modal-header{vertical-align:middle;padding:1%;height:60px;background-repeat:repeat-x;background-image:linear-gradient(45deg,#007dc3,#0054a4);color:#fff}app-modal[_ngcontent-sc65]     .remax-modal>.content{padding:0;width:450px}app-modal[_ngcontent-sc65]     .close-ic{color:#fff}app-modal[_ngcontent-sc65]     .header-save-search{margin-top:10px}.filters[_ngcontent-sc65]{flex:4;z-index:3}h1[_ngcontent-sc65]{font-size:20px;color:#004e9b}div.extra-nav.RESIDENTIAL[_ngcontent-sc65]{color:#007dc3}div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]{fill:#007dc3}div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   path[_ngcontent-sc65], div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   rect[_ngcontent-sc65]{fill:#007dc3;stroke:#007dc3}div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   circle[_ngcontent-sc65]{stroke:#007dc3}div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   svg.view-map[_ngcontent-sc65]   g[_ngcontent-sc65], div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   svg.view-map[_ngcontent-sc65]   g[_ngcontent-sc65]   circle[_ngcontent-sc65], div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   svg.view-map[_ngcontent-sc65]   g[_ngcontent-sc65]   path[_ngcontent-sc65]{fill:#fff}div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   div.save-search[_ngcontent-sc65]   g[_ngcontent-sc65]   path[_ngcontent-sc65]{fill:#007dc3}div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   app-search-bar[_ngcontent-sc65]     app-input .remax-input input{border-color:#007dc3}div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   app-search-bar[_ngcontent-sc65]     app-input ellipse, div.extra-nav.RESIDENTIAL[_ngcontent-sc65]   app-search-bar[_ngcontent-sc65]     app-input g path{fill:#007dc3}div.extra-nav.LUXURY[_ngcontent-sc65]{color:#002e5c}div.extra-nav.LUXURY[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]{fill:#002e5c}div.extra-nav.LUXURY[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   path[_ngcontent-sc65], div.extra-nav.LUXURY[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   rect[_ngcontent-sc65]{fill:#002e5c;stroke:#002e5c}div.extra-nav.LUXURY[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   circle[_ngcontent-sc65]{stroke:#002e5c}div.extra-nav.LUXURY[_ngcontent-sc65]   svg.view-map[_ngcontent-sc65]   g[_ngcontent-sc65], div.extra-nav.LUXURY[_ngcontent-sc65]   svg.view-map[_ngcontent-sc65]   g[_ngcontent-sc65]   circle[_ngcontent-sc65], div.extra-nav.LUXURY[_ngcontent-sc65]   svg.view-map[_ngcontent-sc65]   g[_ngcontent-sc65]   path[_ngcontent-sc65]{fill:#fff}div.extra-nav.LUXURY[_ngcontent-sc65]   div.save-search[_ngcontent-sc65]   g[_ngcontent-sc65]   path[_ngcontent-sc65]{fill:#002e5c}div.extra-nav.LUXURY[_ngcontent-sc65]   app-search-bar[_ngcontent-sc65]     app-input .remax-input input{border-color:#002e5c}div.extra-nav.LUXURY[_ngcontent-sc65]   app-search-bar[_ngcontent-sc65]     app-input ellipse, div.extra-nav.LUXURY[_ngcontent-sc65]   app-search-bar[_ngcontent-sc65]     app-input g path{fill:#002e5c}div.extra-nav.COMMERCIAL[_ngcontent-sc65]{color:#2d2d2d}div.extra-nav.COMMERCIAL[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]{fill:#2d2d2d}div.extra-nav.COMMERCIAL[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   path[_ngcontent-sc65], div.extra-nav.COMMERCIAL[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   rect[_ngcontent-sc65]{fill:#2d2d2d;stroke:#2d2d2d}div.extra-nav.COMMERCIAL[_ngcontent-sc65]   div.expand-gallery[_ngcontent-sc65]   g[_ngcontent-sc65]   circle[_ngcontent-sc65]{stroke:#2d2d2d}div.extra-nav.COMMERCIAL[_ngcon ...
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    @media (min-width:600px){.content-wrapper[_ngcontent-sc65]{display:flex;height:-o-calc(100% - 60px);height:calc(100% - 60px)}.content-wrapper[_ngcontent-sc65]   app-google-map[_ngcontent-sc65]{flex:1}}@media (min-width:900px){app-sub-nav[_ngcontent-sc65]{position:absolute;width:100%;left:0}.content-wrapper[_ngcontent-sc65]{display:flex;margin-top:60px;height:-o-calc(100% - 60px);height:calc(100% - 60px)}.content-wrapper[_ngcontent-sc65]   app-google-map[_ngcontent-sc65]{flex:1}.content-wrapper[_ngcontent-sc65]   app-gallery-view-desktop[_ngcontent-sc65]{width:310px;background-color:#fff;height:-o-calc(100vh - 120px);height:calc(100vh - 120px)}.extra-nav[_ngcontent-sc65]{left:0;display:flex;justify-content:flex-end;height:60px;width:100%;color:#007dc3;background-color:#fff;padding:0 5vw;border-bottom:1px solid #dcdcdc}.extra-nav[_ngcontent-sc65]   .expand-gallery[_ngcontent-sc65]   #expand-icon[_ngcontent-sc65]{transition:-webkit-transform .2s cubic-bezier(.075,.82,.165,1);transition:transform .2s cubic-bezier(.075,.82,.165,1);transition:transform .2s cubic-bezier(.075,.82,.165,1),-webkit-transform .2s cubic-bezier(.075,.82,.165,1)}.extra-nav[_ngcontent-sc65]   .expand-gallery[_ngcontent-sc65], .extra-nav[_ngcontent-sc65]   .save-search[_ngcontent-sc65], .extra-nav[_ngcontent-sc65]   .share-search[_ngcontent-sc65]{padding:0 10px}.extra-nav[_ngcontent-sc65]   .expand-gallery[_ngcontent-sc65]   img[_ngcontent-sc65], .extra-nav[_ngcontent-sc65]   .save-search[_ngcontent-sc65]   img[_ngcontent-sc65], .extra-nav[_ngcontent-sc65]   .share-search[_ngcontent-sc65]   img[_ngcontent-sc65]{width:30px;height:30px}.extra-nav[_ngcontent-sc65]   .share-search[_ngcontent-sc65]{border-left:1px dotted #007dc3;border-right:1px dotted #007dc3}}@media (min-width:1200px){.content-wrapper[_ngcontent-sc65]   app-gallery-view-desktop[_ngcontent-sc65]{width:620px;background-color:#fff;height:-o-calc(100vh - 222px);height:calc(100vh - 222px)}app-search-bar[_ngcontent-sc65]     .form-group{margin-bottom:0;margin-right:10px}.full-search[_ngcontent-sc65]{flex-grow:1.5}.extra-nav[_ngcontent-sc65]{padding:0 5%;border-bottom:1px solid #dcdcdc}}@media (min-width:1800px){.extra-nav[_ngcontent-sc65]{padding:0 12%}}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .gallery-container[_ngcontent-sc71]{min-height:400px;padding:10px;margin-bottom:40px}.gallery-header[_ngcontent-sc71]{font-size:20px;color:#004e9b}.top-info[_ngcontent-sc71]{padding:2%}[_nghost-sc71]     .remax-notification.mobile-only{position:relative}@media (min-width:600px){.gallery-wrapper[_ngcontent-sc71]{background-color:#fff;box-shadow:0 2px 4px 0 rgba(0,0,0,.1);border-radius:2px}}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    app-listing-card[_ngcontent-sc71]{width:100%;margin-bottom:10px}.more-listings-separator[_ngcontent-sc71]{text-align:center;font-size:2.5rem;font-weight:700}@media (min-width:600px){app-listing-card[_ngcontent-sc71]{width:48%;margin:1%}}@media (min-width:900px){app-listing-card[_ngcontent-sc71]{width:32%;margin:1% .66%}}@media (min-width:1200px){app-listing-card[_ngcontent-sc71]{width:23%;margin:1%}}@media (max-width:1199px){[_nghost-sc71]{background-color:#fff}}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .mobile-only[_ngcontent-sc74]{margin-bottom:0;z-index:2;width:100%;background-color:rgba(0,0,0,.5);border:0;color:#fff;border-radius:0}@media (min-width:766px){.mobile-only[_ngcontent-sc74]{display:none}}.desktop-only[_ngcontent-sc74]{margin-left:2%}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .remax-gradient-blue[_ngcontent-sc39]{background-image:linear-gradient(90deg,#0054a4 0,#002b5c 100%);background-repeat:repeat-x}.remax-gradient-dark-blue[_ngcontent-sc39]{background-image:linear-gradient(28.79898555deg,#1159ac 0,#20345d 100%);background-repeat:repeat-x}.remax-gradient-gray[_ngcontent-sc39]{background-image:linear-gradient(90deg,#454647 0,#1e1c1c 100%);background-repeat:repeat-x}.remax-gradient-red[_ngcontent-sc39]{background-image:linear-gradient(90deg,#e11b22 0,#b30b30 100%);background-repeat:repeat-x}.remax-gradient-white[_ngcontent-sc39]{background-image:linear-gradient(90deg,#fbfcfd 0,#f6f7f9 100%);background-repeat:repeat-x}.remax-gradient-light-blue[_ngcontent-sc39]{background-image:linear-gradient(45deg,#0086cb 0,#1f335e 100%);background-repeat:repeat-x}.content[_ngcontent-sc39], .remax-basic-box-shadow[_ngcontent-sc39]{box-shadow:0 2px 4px 0 rgba(0,0,0,.1)}.remax-modal[_ngcontent-sc39]{top:0;bottom:0;left:0;right:0;z-index:100;overflow-y:auto}.remax-modal--redesign[_ngcontent-sc39]   .content[_ngcontent-sc39]{padding:.8% .5% .5%}.remax-modal--redesign[_ngcontent-sc39]   .content[_ngcontent-sc39]   .close-ic[_ngcontent-sc39]{right:15px;color:#007dc3}.background[_ngcontent-sc39]{opacity:.6;background-color:#000;z-index:-1;top:0;left:0;right:0;bottom:0}.content[_ngcontent-sc39]{max-height:100%;background-color:#fff;width:70%;padding:2% .5% .5%;overflow-y:auto}@media (min-width:1800px){.content[_ngcontent-sc39]{width:50%}}.content.medium[_ngcontent-sc39]{width:35%}@media (max-width:1799px){.content.full-expansion[_ngcontent-sc39]{height:100%}}.isOnLandingPage[_ngcontent-sc39]{position:fixed;width:100%;height:100%;overflow:auto}.close-ic[_ngcontent-sc39]{top:16px;right:25px;cursor:pointer;color:#004e9b;font-weight:bolder}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .gallery-pagination[_ngcontent-sc77]{padding:0 25px;margin-bottom:45px;flex-wrap:wrap}.gallery-pagination[_ngcontent-sc77]   .pagination-item[_ngcontent-sc77]{display:block;margin:6px;padding:0 6px;min-width:40px;height:40px;line-height:40px;border:1px solid #007dc3;color:#007dc3;cursor:pointer}.gallery-pagination[_ngcontent-sc77]   .pagination-item[_ngcontent-sc77]   span[_ngcontent-sc77]{margin-right:5px;margin-left:5px}.gallery-pagination[_ngcontent-sc77]   .pagination-item[_ngcontent-sc77]:focus, .gallery-pagination[_ngcontent-sc77]   .pagination-item[_ngcontent-sc77]:hover{background-color:#004e9b;color:#fff}.gallery-pagination[_ngcontent-sc77]   .pagination-item.selected[_ngcontent-sc77]{background-color:#007dc3;color:#fff}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    aside[_ngcontent-sc23]{z-index:100;cursor:progress;top:0;bottom:0;left:0;right:0}.background[_ngcontent-sc23]{background-color:#fff;opacity:.95;height:100%;width:100%;z-index:0}.rm-loader[_ngcontent-sc23]{max-width:200px}.loader-wrapper[_ngcontent-sc23]{z-index:1}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    @media (min-width:900px){aside[_ngcontent-sc23]{align-items:center;justify-content:center}}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .balloon[_ngcontent-sc73]{justify-content:center;margin-bottom:40px}.balloon[_ngcontent-sc73]   img[_ngcontent-sc73]{width:145px;height:184px}.logo[_ngcontent-sc73]{justify-content:center;margin-bottom:40px}.logo[_ngcontent-sc73]   img[_ngcontent-sc73]{width:150px;height:60px}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .gallery-header[_ngcontent-sc72]{font-size:20px}@media (min-width:600px){.gallery-header[_ngcontent-sc72]{padding:7px 0 0;color:#004e9b}.top-info[_ngcontent-sc72]{padding:15px 25px 5px;display:flex;flex-direction:column;width:310px;align-self:flex-end}.top-info[_ngcontent-sc72]   .filters[_ngcontent-sc72]{flex-direction:column}.gallery-container-desktop[_ngcontent-sc72]{overflow-y:scroll;flex-shrink:1}.gallery-container-desktop[_ngcontent-sc72]   .gallery-container[_ngcontent-sc72]{background-color:#fff;flex-wrap:wrap;margin:0;justify-content:space-between;align-content:flex-start;padding:10px 25px}.full-width[_nghost-sc72]   .gallery-container-desktop[_ngcontent-sc72]   .gallery-container[_ngcontent-sc72]{padding:10px 5%}[_nghost-sc72]   .gallery-container[_ngcontent-sc72]   app-listing-card[_ngcontent-sc72]{width:99%;max-width:265px;margin:5px 2px}[_nghost-sc72]   .near-me[_ngcontent-sc72]     input{border:0;border-bottom:1px solid #c4c6c8;box-shadow:none;border-radius:0}.invisible-box[_ngcontent-sc72]{width:270px}}@media (min-width:1200px){.gallery-header[_ngcontent-sc72]{padding:7px 0 0;color:#004e9b}.top-info[_ngcontent-sc72]{width:620px}.top-info[_ngcontent-sc72]   .filters[_ngcontent-sc72]{flex-direction:row}.full-width[_nghost-sc72]   .top-info[_ngcontent-sc72]{margin-right:5%}[_nghost-sc72]   .gallery-container[_ngcontent-sc72]   app-listing-card[_ngcontent-sc72]{width:49%}}@media (min-width:1800px){.gallery-header[_ngcontent-sc72]{color:#004e9b}.full-width[_nghost-sc72]   .top-info[_ngcontent-sc72]{margin-right:12%}.full-width[_nghost-sc72]   .gallery-container-desktop[_ngcontent-sc72]   .gallery-container[_ngcontent-sc72]{padding:10px 12%}}@media only screen and (min-width:1200px){.breadcrumbs[_ngcontent-sc72]{padding-left:25px}}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .dropdown-caret[_ngcontent-sc76]{color:#007dc3;border-left:1px solid #007dc3;right:5px;top:5px;z-index:0}select[_ngcontent-sc76]{cursor:pointer;color:#007dc3;border-color:#007dc3;-webkit-appearance:none;-moz-appearance:none;appearance:none;position:relative;z-index:1;background:0 0;margin-right:25px;border-radius:4px}@media all and (-ms-high-contrast:none),(-ms-high-contrast:active){select[_ngcontent-sc76]::-ms-expand{display:none}}select[_ngcontent-sc76]   option[disabled][_ngcontent-sc76]{display:none}.select-wrapper[_ngcontent-sc76]{background-color:#fff}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .back[_ngcontent-sc5]{color:#0054a4}[_nghost-sc5]     app-input{z-index:3}[_nghost-sc5]     app-input input{padding-left:30px;padding-right:30px}[_nghost-sc5]     app-input svg{top:7px;left:10px}[_nghost-sc5]     app-input .place{top:5px;color:#dc1c2e}[_nghost-sc5]     app-input .clear-ic{right:10px;top:25%}[_nghost-sc5]     app-input.icon-right input{padding-left:10px;padding-right:30px}[_nghost-sc5]     app-input.icon-right svg{right:10px;left:inherit}@media (max-width:1199px){.search-bar-container[_ngcontent-sc5]{padding-top:5px;padding-right:10px}}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .remax-input--redesign[_ngcontent-sc44]   label[_ngcontent-sc44]{color:#1f355e;font-size:14px;font-weight:500;line-height:17px}.remax-input.full-width[_ngcontent-sc44]{width:100%}.remax-input[_ngcontent-sc44]   input[_ngcontent-sc44]{background-color:#fff;border-color:#007dc3;border-radius:4px}.remax-input[_ngcontent-sc44]   input[_ngcontent-sc44]:disabled{background-color:#edeff0}.remax-input[_ngcontent-sc44]   input[_ngcontent-sc44]:focus{box-shadow:inset 0 0 3px 2px Highlight}.commercial.remax-input--redesign[_ngcontent-sc44]   label[_ngcontent-sc44]{color:#3b3b3b}.inline-input.input-mobile[_ngcontent-sc44]{display:block}.inline-input.input-mobile[_ngcontent-sc44]   label[_ngcontent-sc44]{font-weight:Normal;font-size:14px}.inline-input.input-mobile[_ngcontent-sc44]   input[_ngcontent-sc44]{margin-left:0;width:284px}.inline-input.input-desktop[_ngcontent-sc44]{display:flex;align-items:center}.inline-input.input-desktop[_ngcontent-sc44]   label[_ngcontent-sc44]{font-weight:Normal;font-size:14px}.inline-input.input-desktop[_ngcontent-sc44]   input[_ngcontent-sc44]{margin-left:10px;width:300px}.custom-form-control-height[_ngcontent-sc44]{height:48px!important}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    hr[_ngcontent-sc67]{margin-top:10px;margin-bottom:10px}[_nghost-sc67]     .remax-select{display:flex;justify-content:space-between}[_nghost-sc67]     label, label[_ngcontent-sc67]{font-weight:700;font-size:1.5rem;text-transform:capitalize;color:#20222a;-ms-grid-row-align:center;align-self:center}app-switch[_ngcontent-sc67]     label{font-size:inherit;font-weight:400}app-switch[_ngcontent-sc67]     div.full-width{margin-bottom:10px}
#   </style>
#   <style ng-transition-rmx="remaxdotca">
#    .remax-gradient-blue[_ngcontent-sc67]{background-image:linear-gradient(90deg,#0054a4 0,#002b5c 100%);background-repeat:repeat-x}.remax-gradient-dark-blue[_ngcontent-sc67]{background-image:linear-gradient(28.79898555deg,#1159ac 0,#20345d 100%);background-repeat:repeat-x}.remax-gradient-gray[_ngcontent-sc67]{background-image:linear-gradient(90deg,#454647 0,#1e1c1c 100%);background-repeat:repeat-x}.remax-gradient-red[_ngcontent-sc67]{background-image:linear-gradient(90deg,#e11b22 0,#b30b30 100%);background-repeat:repeat-x}.remax-gradient-white[_ngcontent-sc67]{background-image:linear-gradient(90deg,#fbfcfd 0,#f6f7f9 100%);background-repeat:repeat-x}.remax-gradient-light-blue[_ngcontent-sc67]{background-image:linear-gradient(45deg,#0086cb 0,#1f335e 100%);background-repeat:repeat-x}.pseudo-dropdown[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67], .remax-basic-box-shadow[_ngcontent-sc67], form.COMMERCIAL[_ngcontent-sc67]   app-switch[_ngcontent-sc67]     .onoffswitch-checkbox:checked, form.LUXURY[_ngcontent-sc67]   app-switch[_ngcontent-sc67]     .onoffswitch-checkbox:checked, form.RESIDENTIAL[_ngcontent-sc67]   app-switch[_ngcontent-sc67]     .onoffswitch-checkbox:checked{box-shadow:0 2px 4px 0 rgba(0,0,0,.1)}form.RESIDENTIAL[_ngcontent-sc67]   .select-wrapper[_ngcontent-sc67]{color:#007dc3;border:1px solid #007dc3}form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-caret[_ngcontent-sc67]{color:#007dc3;border-left:1px solid #007dc3}form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]{border:1px solid #007dc3}form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]   .inner-pseudo-dropdown[_ngcontent-sc67] > .select-wrapper[_ngcontent-sc67], form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]   app-select[_ngcontent-sc67]     .select-wrapper{background-color:#007dc3;color:#fff;border-color:#007dc3}form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]   .inner-pseudo-dropdown[_ngcontent-sc67] > .select-wrapper[_ngcontent-sc67]   select[_ngcontent-sc67], form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]   app-select[_ngcontent-sc67]     .select-wrapper select{color:#fff}form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]   .inner-pseudo-dropdown[_ngcontent-sc67] > .select-wrapper[_ngcontent-sc67]   option[_ngcontent-sc67], form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]   app-select[_ngcontent-sc67]     .select-wrapper option{color:#007dc3}form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]   .inner-pseudo-dropdown[_ngcontent-sc67] > .select-wrapper[_ngcontent-sc67]   .dropdown-caret[_ngcontent-sc67], form.RESIDENTIAL[_ngcontent-sc67]   .dropdown-content[_ngcontent-sc67]   app-select[_ngcontent-sc67]     .select-wrapper .dropdown-caret{border-color:#fff;color:#fff}form.RESIDENTIAL[_ngcontent-sc67]   app-select[_ngcontent-sc67]     i, form.RESIDENTIAL[_ngcontent-sc67]   app-select[_ngcontent-sc67]     select.form-control{color:#007dc3;border-color:#007dc3}form.RESIDENTIAL[_ngcontent-sc67]   app-select[_ngcontent-sc67]     label{color:#007dc3;-ms-grid-row-align:auto;align-self:auto}form.RESIDENTIAL[_ngcontent-sc67]   app-select[_ngcontent-sc67]     .remax-select{flex-direction:column}form.RESIDENTIAL[_ngcontent-sc67]   app-checkbox[_ngcontent-sc67]     span{color:#007dc3;border-color:#007dc3}form.RESIDENTIAL[_ngcontent-sc67]   app-checkbox[_ngcontent-sc67]     g>rect{stroke:#007dc3}form.RESIDENTIAL[_ngcontent-sc67]   app-checkbox[_ngcontent-sc67]     div.checked use{fill:#007dc3}form.RESIDENTIAL[_ngcontent-sc67]   app-switch[_ngcontent-sc67]     label{color:#007dc3}form.RESIDENTIAL[_ngcontent-sc67]   app-switch[_ngcontent-sc67]     .onoffswitch-checkbox:checked{background-color:#fff}form.RESIDENTIAL[_ngcontent-sc67]   app-switch[_ngcontent-sc67]     .onoffswitch-checkbox:checked+.onoffswitch-box{background-repeat:repeat-x;background-image:linear-gradient(45deg,#007dc3,#007dc3);border:#0 ...
#   </style>
#   <style ng-transition-rmx="remaxdotca">
# ...
#                     </desc>
#                     <defs _ngcontent-sc21="">
#                     </defs>
#                     <g _ngcontent-sc21="" fill="none" fill-rule="evenodd" opacity="1.00" stroke="none" stroke-width="1" transform="translate(-201.000000, -710.000000)">
#                      <g _ngcontent-sc21="" fill="#004E9B" transform="translate(64.000000, 676.000000)">
#                       <g _ngcontent-sc21="" transform="translate(0.000000, 28.000000)">
#                        <g _ngcontent-sc21="" transform="translate(10.625000, 5.507812)">
#                         <path _ngcontent-sc21="" d="M134.433705,0.537913223 C129.583175,0.537913223 127.1375,4.01553643 127.1375,6.91555897 C127.1375,8.67149222 127.802296,10.2336447 129.228156,10.8157809 C129.461963,10.9113673 129.671391,10.8190691 129.739198,10.5602033 C129.786367,10.3810496 129.897941,9.92908332 129.947719,9.74085853 C130.016092,9.48482745 129.989559,9.39502381 129.800881,9.17187537 C129.389734,8.68691305 129.127013,8.0590813 129.127013,7.16977583 C129.127013,4.58973545 131.057338,2.28001309 134.153523,2.28001309 C136.895142,2.28001309 138.401393,3.95521379 138.401393,6.19248094 C138.401393,9.13615802 137.098674,11.620612 135.164721,11.620612 C134.096602,11.620612 133.2971,10.7373161 133.553471,9.65400299 C133.8603,8.36069453 134.454796,6.96488294 134.454796,6.03135597 C134.454796,5.19568323 134.006231,4.49868454 133.077807,4.49868454 C131.985989,4.49868454 131.10893,5.62814671 131.10893,7.14120195 C131.10893,8.10489023 131.434581,8.75664694 131.434581,8.75664694 C131.434581,8.75664694 130.317252,13.4907274 130.12143,14.3197102 C129.731374,15.9708725 130.062808,17.9949694 130.090815,18.1994088 C130.107256,18.3205076 130.262939,18.3493083 130.333466,18.2578038 C130.434155,18.1263866 131.734494,16.5210332 132.176595,14.9169271 C132.301663,14.462693 132.894684,12.1106768 132.894684,12.1106768 C133.249363,12.7872655 134.286074,13.3832351 135.388549,13.3832351 C138.670464,13.3832351 140.897073,10.3912546 140.897073,6.38637516 C140.897073,3.35822369 138.332113,0.537913223 134.433705,0.537913223 L134.433705,0.537913223 Z" id="pinterest-svg">
#                         </path>
#                        </g>
#                       </g>
#                      </g>
#                     </g>
#                    </svg>
#                   </a>
#                   <!-- -->
#                  </div>
#                  <!-- -->
#                 </div>
#                </div>
#               </app-connect-social-bar>
#               <hr _ngcontent-sc8=""/>
#              </div>
#             </div>
#            </nav>
#            <section _ngcontent-sc8="" class="copyright-block text-center has-pos-rel">
#             <!-- -->
#             <p _ngcontent-sc8="" class="find-online" translate="footer.find-us-online">
#              Find us online
#             </p>
#             <div _ngcontent-sc8="" class="logos">
#              <hr _ngcontent-sc8=""/>
#              <app-connect-social-bar _ngcontent-sc8="" _nghost-sc21="" facebook="https://www.facebook.com/REMAXno1/" pinterest="remaxca/?autologin=true" twitter="REMAXca">
#               <div _ngcontent-sc21="" class="social-media">
#                <!-- -->
#                <div _ngcontent-sc21="" class="social-links is-flex-column">
#                 <!-- -->
#                 <div _ngcontent-sc21="" class="is-flex has-flex-align-center has-flex-content-space-around icons-wrapper ng-star-inserted">
#                  <!-- -->
#                  <a _ngcontent-sc21="" class="ng-star-inserted" href="https://www.facebook.com/REMAXno1/" rel="noopener" target="_blank" title="Go to agent's Facebook">
#                   <svg _ngcontent-sc21="" height="15px" version="1.1" viewbox="0 0 10 21" width="10px" xmlns="http://www.w3.org/2000/svg">
#                    <title _ngcontent-sc21="">
#                     facebook
#                    </title>
#                    <desc _ngcontent-sc21="">
#                     Created with Sketch.
#                    </desc>
#                    <g _ngcontent-sc21="" fill="none" fill-rule="evenodd">
#                     <g _ngcontent-sc21="" fill="#004E9B" fill-rule="nonzero" transform="translate(-65 -313)">
#                      <g _ngcontent-sc21="" transform="translate(65 313)">
#                       <path _ngcontent-sc21="" d="m9.758 6.7999h-3.3232v-2.1795c0-0.81853 0.5425-1.0094 0.92459-1.0094h2.3452v-3.5984l-3.2298-0.012606c-3.5853 0-4.4013 2.6838-4.4013 4.4013v2.3986h-2.0735v3.7079h2.0735v10.492h4.3613v-10.492h2.9429l0.38036-3.7079z">
#                       </path>
#                      </g>
#                     </g>
#                    </g>
#                   </svg>
#                  </a>
#                  <!-- -->
#                  <!-- -->
#                  <a _ngcontent-sc21="" class="ng-star-inserted" href="https://twitter.com/REMAXca" rel="noopener" target="_blank" title="Go to agent's Twitter">
#                   <svg _ngcontent-sc21="" height="12px" version="1.1" viewbox="0 0 23 18" width="23px" xmlns="http://www.w3.org/2000/svg">
#                    <title _ngcontent-sc21="">
#                     twitter
#                    </title>
#                    <desc _ngcontent-sc21="">
#                     Created with Sketch.
#                    </desc>
#                    <g _ngcontent-sc21="" fill="none" fill-rule="evenodd">
#                     <g _ngcontent-sc21="" fill="#004E9B" fill-rule="nonzero" transform="translate(-146 -317)">
#                      <g _ngcontent-sc21="" transform="translate(65 313)">
#                       <g _ngcontent-sc21="" transform="translate(81 4)">
#                        <path _ngcontent-sc21="" d="m22.11 2.1435c-0.81379 0.3606-1.687 0.60515-2.6044 0.71433 0.93677-0.56096 1.6538-1.4507 1.9937-2.5077-0.87871 0.51949-1.8486 0.8967-2.8821 1.1012-0.82759-0.88286-2.0048-1.4328-3.3104-1.4328-2.5049 0-4.5359 2.031-4.5359 4.5346 0 0.35507 0.040066 0.70186 0.11745 1.0335-3.7691-0.18931-7.1113-1.9951-9.3482-4.7391-0.39102 0.66873-0.61346 1.4479-0.61346 2.2797 0 1.5737 0.80136 2.9623 2.0172 3.7746-0.74334-0.024856-1.4425-0.22934-2.0545-0.56924v0.056649c0 2.1968 1.564 4.0302 3.6379 4.4475-0.37996 0.10224-0.78062 0.15889-1.1951 0.15889-0.29289 0-0.57614-0.029011-0.85385-0.084287 0.57751 1.803 2.2521 3.1142 4.2361 3.1502-1.5516 1.2159-3.508 1.9385-5.633 1.9385-0.36612 0-0.72675-0.02211-1.0818-0.062176 2.0075 1.2891 4.3909 2.0407 6.9524 2.0407 8.3437 0 12.905-6.911 12.905-12.905l-0.01521-0.58719c0.89114-0.6356 1.6621-1.4342 2.2686-2.3433z">
#                        </path>
#                       </g>
#                      </g>
#                     </g>
#                    </g>
#                   </svg>
#                  </a>
#                  <!-- -->
#                  <a _ngcontent-sc21="" class="ng-star-inserted" href="https://pinterest.ca/remaxca/?autologin=true" rel="noopener" target="_blank" title="Go to agent's Pinterest">
#                   <svg _ngcontent-sc21="" height="18px" version="1.1" viewbox="0 0 15 18" width="15px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#                    <title _ngcontent-sc21="">
#                     Pinterest
#                    </title>
#                    <desc _ngcontent-sc21="">
#                     Created with Sketch.
#                    </desc>
#                    <defs _ngcontent-sc21="">
#                    </defs>
#                    <g _ngcontent-sc21="" fill="none" fill-rule="evenodd" opacity="1.00" stroke="none" stroke-width="1" transform="translate(-201.000000, -710.000000)">
#                     <g _ngcontent-sc21="" fill="#004E9B" transform="translate(64.000000, 676.000000)">
#                      <g _ngcontent-sc21="" transform="translate(0.000000, 28.000000)">
#                       <g _ngcontent-sc21="" transform="translate(10.625000, 5.507812)">
#                        <path _ngcontent-sc21="" d="M134.433705,0.537913223 C129.583175,0.537913223 127.1375,4.01553643 127.1375,6.91555897 C127.1375,8.67149222 127.802296,10.2336447 129.228156,10.8157809 C129.461963,10.9113673 129.671391,10.8190691 129.739198,10.5602033 C129.786367,10.3810496 129.897941,9.92908332 129.947719,9.74085853 C130.016092,9.48482745 129.989559,9.39502381 129.800881,9.17187537 C129.389734,8.68691305 129.127013,8.0590813 129.127013,7.16977583 C129.127013,4.58973545 131.057338,2.28001309 134.153523,2.28001309 C136.895142,2.28001309 138.401393,3.95521379 138.401393,6.19248094 C138.401393,9.13615802 137.098674,11.620612 135.164721,11.620612 C134.096602,11.620612 133.2971,10.7373161 133.553471,9.65400299 C133.8603,8.36069453 134.454796,6.96488294 134.454796,6.03135597 C134.454796,5.19568323 134.006231,4.49868454 133.077807,4.49868454 C131.985989,4.49868454 131.10893,5.62814671 131.10893,7.14120195 C131.10893,8.10489023 131.434581,8.75664694 131.434581,8.75664694 C131.434581,8.75664694 130.317252,13.4907274 130.12143,14.3197102 C129.731374,15.9708725 130.062808,17.9949694 130.090815,18.1994088 C130.107256,18.3205076 130.262939,18.3493083 130.333466,18.2578038 C130.434155,18.1263866 131.734494,16.5210332 132.176595,14.9169271 C132.301663,14.462693 132.894684,12.1106768 132.894684,12.1106768 C133.249363,12.7872655 134.286074,13.3832351 135.388549,13.3832351 C138.670464,13.3832351 140.897073,10.3912546 140.897073,6.38637516 C140.897073,3.35822369 138.332113,0.537913223 134.433705,0.537913223 L134.433705,0.537913223 Z" id="pinterest-svg">
#                        </path>
#                       </g>
#                      </g>
#                     </g>
#                    </g>
#                   </svg>
#                  </a>
#                  <!-- -->
#                 </div>
#                 <!-- -->
#                </div>
#               </div>
#              </app-connect-social-bar>
#              <hr _ngcontent-sc8=""/>
#             </div>
#             <p _ngcontent-sc8="" class="copyright">
#              Copyright Â© 2020 RE/MAX.
#             </p>
#             <p _ngcontent-sc8="" class="rights" translate="footer.rights-reserved">
#              All rights reserved.
#             </p>
#             <p _ngcontent-sc8="" class="associated-logos" translate="footer.trademarks">
#              The trademarks MLSÂ®, Multiple Listing ServiceÂ® and the associated logos identify professional services rendered by REALTORÂ® members of CREA to effect the purchase, sale and lease of real estate as part of a cooperative selling system.
#             </p>
#            </section>
#           </footer>
#          </app-footer>
#         </div>
#         <!-- -->
#        </app-gallery-view-desktop>
#        <app-notifications _ngcontent-sc65="" _nghost-sc74="" class="ng-tns-c74-5">
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <div _ngcontent-sc74="" class="hide-on-tablet-up remax-notification alert mobile-only has-pos-fix text-center ng-tns-c74-5 ng-trigger ng-trigger-bottomNotification ng-star-inserted" role="alert" style="">
#         </div>
#        </app-notifications>
#        <app-modal _ngcontent-sc65="" _nghost-sc39="" class="hide-on-tablet-down">
#         <!-- -->
#        </app-modal>
#        <!-- -->
#        <!-- -->
#       </div>
#      </app-home-page>
#      <router-outlet _ngcontent-sc0="" class="ng-tns-c0-0" name="popup">
#      </router-outlet>
#      <!-- -->
#     </div>
#     <!-- -->
#     <!-- -->
#     <app-drawer _ngcontent-sc0="" _nghost-sc9="" class="main-drawer ng-tns-c9-2">
#      <!-- -->
#     </app-drawer>
#     <!-- -->
#     <!-- -->
#    </div>
#   </app-root>
#   <script src="https://remax-prodapp.imgix.net/runtime.c50c31498ab110eb18ea.js" type="text/javascript">
#   </script>
#   <script src="https://remax-prodapp.imgix.net/polyfills.46687cc55c8a5c18f124.js" type="text/javascript">
#   </script>
#   <script src="https://remax-prodapp.imgix.net/scripts.92a65c5b3c9e0ba27d9b.js" type="text/javascript">
#   </script>
#   <script src="https://remax-prodapp.imgix.net/vendor.682866675389fc5657b3.js" type="text/javascript">
#   </script>
#   <script src="https://remax-prodapp.imgix.net/main.c82b0d2fb2b3fed555a6.js" type="text/javascript">
#   </script>
#   <script id="remaxdotca-state" type="application/json">
#    {&q;G./api/v1/listings/count/ab/calgary&q;:{&q;body&q;:{&q;result&q;:0,&q;requestId&q;:&q;1f63debaefa24aa8906326d0e17aedf8&q;},&q;headers&q;:{&q;date&q;:[&q;Sat, 26 Sep 2020 20:59:15 GMT&q;],&q;content-type&q;:[&q;application/json; charset=utf-8&q;],&q;transfer-encoding&q;:[&q;chunked&q;],&q;connection&q;:[&q;keep-alive&q;],&q;server&q;:[&q;Kestrel&q;],&q;api-supported-versions&q;:[&q;1.0&q;]},&q;status&q;:200,&q;statusText&q;:&q;OK&q;,&q;url&q;:&q;https://api.remax.ca/api/v1/listings/count/ab/calgary&q;},&q;G.https://api.remax.ca/api/v1/listings/count/ab/calgary&q;:{&q;body&q;:{&q;result&q;:0,&q;requestId&q;:&q;1f63debaefa24aa8906326d0e17aedf8&q;},&q;headers&q;:{&q;date&q;:[&q;Sat, 26 Sep 2020 20:59:15 GMT&q;],&q;content-type&q;:[&q;application/json; charset=utf-8&q;],&q;transfer-encoding&q;:[&q;chunked&q;],&q;connection&q;:[&q;keep-alive&q;],&q;server&q;:[&q;Kestrel&q;],&q;api-supported-versions&q;:[&q;1.0&q;]},&q;status&q;:200,&q;statusText&q;:&q;OK&q;,&q;url&q;:&q;https://api.remax.ca/api/v1/listings/count/ab/calgary&q;},&q;G.https://remax-prodapp.imgix.net/assets/i18n/en.1.0.0.1737.json&q;:{&q;body&q;:{&q;REMAX&q;:&q;REMAX ENGLISH&q;,&q;for&q;:&q;for&q;,&q;in&q;:&q;in&q;,&q;unexpected-error&q;:&q;An unexpected error occured, please try again.&q;,&q;yes&q;:&q;Yes&q;,&q;no&q;:&q;No&q;,&q;more&q;:&q;More&q;,&q;of&q;:&q;of&q;,&q;email&q;:&q;email&q;,&q;na&q;:&q;N/A&q;,&q;x-of-y&q;:&q;{{ x }} of {{ y }}&q;,&q;has-virtual-tour&q;:&q;Has Virtual Tour&q;,&q;had-video&q;:&q;Has Video&q;,&q;market-price&q;:&q;Market Price&q;,&q;carousel&q;:{&q;aria&q;:{&q;re-start&q;:&q;RE/START Your Real Estate Dreams&q;,&q;trusted-brand&q;:&q;Real Estate&s;s Most Trusted Brand&q;,&q;experienced-agents&q;:&q;Real Estate&s;s Most Experienced Agents&q;,&q;re-imagine&q;:&q;RE/IMAGINE What&s;s Possible&q;}},&q;aria&q;:{&q;logo&q;:&q;REMAX Balloon&q;,&q;closeModal&q;:&q;Close this pop-up&q;,&q;modalOpened&q;:&q;Focus has moved inside a pop-up. Press escape key to exit.&q;,&q;target&q;:&q;Target&q;},&q;listing-sitemap&q;:{&q;title&q;:&q;Newest Real Estate in Canada - Find Homes for Sale&q;,&q;headline1&q;:&q;Canada homes and condos for sale. Search the newest 900 listings across all provinces below&q;,&q;or&q;:&q;or&q;,&q;headline2&q;:&q; browse all listings&q;,&q;links-title&q;:&q;Newest Listings&q;,&q;links-headers&q;:{&q;address&q;:&q;Address&q;,&q;price&q;:&q;Price&q;,&q;bedBathSqft&q;:&q;Bed/Bath/Sqft&q;,&q;dateAdded&q;:&q;Date Added&q;},&q;links-body&q;:{&q;for-sale&q;:&q; for sale&q;,&q;for-rent&q;:&q; for rent&q;},&q;meta-tags&q;:{&q;title&q;:&q;New Real Estate Listings in Canada | RE/MAX Canada&q;,&q;description&q;:&q;View all new real estate listings for sale in Canada. Explore houses for sale, condos or townhouses to find the best homes for sale with Canada&s;s #1 Real Estate Brand.&q;,&q;h1&q;:&q;Newest Real Estate in Canada - Find Homes for Sale&q;}},&q;rental-sitemap&q;:{&q;title&q;:&q;Newest Real Estate in Canada - Find Homes for Rent&q;,&q;headline1&q;:&q;Canada homes and condos for rent. Search the newest 900 listings across all provinces below&q;,&q;or&q;:&q;or&q;,&q;headline2&q;:&q; browse all listings&q;,&q;links-title&q;:&q;Newest Listings&q;,&q;links-headers&q;:{&q;address&q;:&q;Address&q;,&q;price&q;:&q;Price&q;,&q;bedBathSqft&q;:&q;Bed/Bath/Sqft&q;,&q;dateAdded&q;:&q;Date Added&q;},&q;links-body&q;:{&q;for-rent&q;:&q; for rent&q;},&q;meta-tags&q;:{&q;title&q;:&q;New Real Estate Rentals in Canada | RE/MAX Canada&q;,&q;description&q;:&q;View all new real estate listings for rent in Canada. Explore houses for rent, condos or townhouses to find the best homes for rent with Canada&s;s #1 Real Estate Brand.&q;,&q;h1&q;:&q;Newest Real Estate in Canada - Find Homes for Rent&q;}},&q;home&q;:{&q;welcome&q;:&q;Welcome&q;,&q;save-search&q;:&q;Save Search&q;,&q;share-search-results&q;:&q;Share Search Results&q;},&q;card&q;:{&q;courtesy&q;:&q;Listing courtesy of&q;,&q;type&q;:&q;Type&q;,&q;language&q;:&q;Language&q;,&q;grade&q;:&q;Grade&q;} ...
#   </script>
#  </body>
# </html>

# %%
lat_all = soup.find_all('script')[4]
lat_all
# Out:
# <script type="application/ld+json">{
#   "@context": "http://schema.org",
#   "@graph": [
#     {
#       "@type": "SingleFamilyResidence",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "3209 29 ST SW, Calgary, AB T3E2L2",
#         "addressLocality": "Calgary",
#         "addressRegion": "AB",
#         "postalCode": "T3E2L2"
#       },
#       "geo": {
#         "@type": "GeoCoordinates",
#         "latitude": 51.026546,
#         "longitude": -114.130027
#       }
#     },
#     {
#       "@type": "House",
#       "address": {
#         "@type": "PostalAddress",
#         "streetAddress": "3209 29 ST SW, Calgary, AB T3E2L2",
#         "addressLocality": "Calgary",
#         "addressRegion": "AB",
#         "postalCode": "T3E2L2"
#       },
#       "geo": {
#         "@type": "GeoCoordinates",
#         "latitude": 51.026546,
#         "longitude": -114.130027
#       },
#       "photo": {
#         "@type": "ImageObject",
#         "url": []
#       }
#     },
#     {
#       "@type": "Offer",
#       "price": 575000,
#       "priceCurrency": "CAD",
#       "url": "/ab/calgary-real-estate/3209-29-street-sw-wp_id281353872-lst"
#     }
#   ]
# }</script>

# %%
string = ', '.join(lat_all)
lat = "latitude"
position_lat = string.find(lat)
latd = string[(position_lat+11):(position_lat+20)]
latd
#position_lat
# Out:
# '51.026546'

# %%
string = ', '.join(lat_all)
long = "longitude"
position_long = string.find(long)
longd = string[(position_long+12):(position_long+23)]
longd
# Out:
# '-114.130027'

# %% [markdown]
# house_details = []
#
# try:
#     addresses = soup.find_all('meta content')
#     for address in addresses:
#         house_details.append(address.text)
# except:
#     house_details.append('None')
#
# house_details

# %%
house_address = []

try:
    addresses = soup.find_all('section', class_='property-details')
    for address in addresses:
        house_address.append(address.text)
except:
    house_address.append('None')

house_address
# Out:
# ['Details for 13 AUBURN BAY GREEN SEProperty Type: Single FamilyProperty Tax: N/ALast Updated: Sun, August 23, 2020Possession: NegotiableProperty Subtype: DetachedRestrictions: None KnownKey Facts for 13 AUBURN BAY GREEN SEMLSÂ® #: A1026227Ownership-Type: N/AYear Built: 2006sqft: 1512.60 SQFTDate Listed: Aug 23, 2020Lot Size: 2874Occupancy: N/ASubdivision: Auburn BayInside of 13 AUBURN BAY GREEN SEHeating: Natural Gas, Forced Air, Fireplace(s)Heating Source: N/AFull Bathrooms: 2Half Bathrooms: 1Rooms: N/AStories: 2Basement: Full, UnfinishedElectric: 100 Amp ServiceFlooring: Carpet, LinoleumInterior Features: Vaulted Ceiling(s), Walk-In Closet(s), See Remarks, Open Floorplan, Kitchen Island, Granite Counters, No Smoking HomeOutside of 13 AUBURN BAY GREEN SEExterior Features: Private YardRoof: Asphalt ShingleWaterfront Features: Lake PrivilegesAccess: Paved LaneFencing: FencedFeatures for 13 AUBURN BAY GREEN SEConstructionMaterials: Wood Frame, Vinyl SidingStructureType: HouseFoundationDetails: ConcreteCommunity Features: Fishing, Lake, Street Lights, Park, Shopping Nearby, Playground, Clubhouse, Schools NearbyParkingFeatures: Stall, Alley Access, Off StreetLaundryFeatures: In BasementFireplaceFeatures: Living Room, Mantle, GasSecurity Features: Smoke Detector(s)Patio And Porch Features: Front Porch, DeckLot Features: Back Lane, Rectangular Lot, LevelCondo: Not a CondoAssociationYN: YAssociationAmenities: Clubhouse, Playground, Beach AccessArchitecturalStyle: 2 StoreyLevels: TwoSee more details keyboard_arrow_down']

# %%
string = ', '.join(house_address)

# %%
s_year = "Year Built"
position_year = string.find(s_year)
year_built = string[(position_year+12):(position_year+16)]
year_built
# Out:
# '2006'

# %%
s_lot = "Lot Size"
position_lot = string.find(s_lot)
lot_size = string[(position_lot+10):(position_lot+14)]
lot_size
# Out:
# '2874'
